# %% [markdown]
# # Performance analysis based on  main_parallelC_timing.ipynb

# %% [markdown]
# # 1. case

# %% [markdown]
# M =10
#
# coordinateValueRange= (-3, 3)
# numberOfParticles = 2
# numberOfConfig = 20
# numberOfIterations = 20             # for thermalisation

# %%
# %matplotlib widget

# %%
import matplotlib.pyplot as plt

# %%
# parallel computation, new thermalised Metropolis samples for optimization, parameters' optimization 
x = [43.72440552711487,0.14399480819702148, 30.080888271331787] 
labels = ['rinnakkaislaskenta', 'uudet termalisoidut Metropolis-datapisteet', "parametrien optimointi"]
explode = [0.2, 0,0]

# %%
plt.figure(figsize = (9,9))
plt.pie(x, labels = labels, startangle = 90, autopct ='%.2f%%', explode = explode )
plt.legend(loc =(0,0))
plt.show()

# %% [markdown]
# # 2. case

# %% [markdown]
# M =10
#
# coordinateValueRange= (-3, 3)
# numberOfParticles = 2
# numberOfConfig = 20
# numberOfIterations = 60             # for thermalisation

# %%
# parallel computation, new thermalised Metropolis samples for optimization, parameters' optimization 
x = [60.69162154197693,0.50735378265380868, 29.11047339439392] 
labels = ['rinnakkaislaskenta', 'uudet termalisoidut Metropolis-datapisteet', "parametrien optimointi"]
explode = [0.2, 0,0]

# %%
font = {'family' : 'monospace',
        'weight' : 'normal',
        'size'   : '14'}
plt.rc('font', **font)

# %%
plt.figure(figsize = (9,9))
plt.pie(x, labels = labels, startangle = 90, autopct ='%.2f%%', explode = explode, shadow =True )
plt.legend(loc =(0,0))
plt.show()
