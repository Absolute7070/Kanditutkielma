# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# # fortran: test helium
# ### 6. run

# %%
# Out:
#            A         B
# 0   0.341938 -0.000748
# 1   0.358002 -0.000517
# 2   0.368482 -0.000641
# 3   0.365694 -0.000664
# 4   0.380015 -0.000596
# 5   0.386030 -0.000817
# 6   0.396174 -0.000661
# 7   0.402319 -0.000594
# 8   0.413755 -0.000653
# 9   0.421306 -0.000624
# 10  0.416684 -0.000662
# 11  0.426485 -0.000680
# 12  0.434506 -0.000821
# 13  0.457625 -0.000759
# 14  0.452620 -0.000631
# 15  0.475919 -0.000618
# 16  0.481141 -0.000687
# 17  0.487146 -0.000724
# 18  0.493372 -0.000642
# 19  0.495826 -0.000633
# 20  0.515537 -0.000722
# 21  0.516190 -0.000810
# 22  0.536813 -0.000670
# 23  0.539307 -0.000864
# 24  0.546281 -0.000926
# 25  0.572668 -0.000845
# 26  0.574251 -0.001466
# 27  0.577444 -0.000721
# 28  0.592031 -0.000653
# 29  0.595101 -0.000856
# 30  0.614953 -0.000744

# %%
df = pd.read_csv('gradient.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
df.A.plot(ax=axes[0])
df.B.plot(ax=axes[1])
fig.suptitle('6. run gradient', fontsize = 16 )
# Out:
# Text(0.5, 0.98, '6. run gradient')

# %%
df = pd.read_csv('parameters.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
df.A.plot(ax=axes[0])
df.B.plot(ax=axes[1])
fig.suptitle('6. run parameters', fontsize = 16 )
# Out:
# Text(0.5, 0.98, '6. run parameters')

# %%
df.B
# Out:
# 0     4.000007
# 1     4.000013
# 2     4.000019
# 3     4.000026
# 4     4.000032
# 5     4.000040
# 6     4.000046
# 7     4.000052
# 8     4.000059
# 9     4.000065
# 10    4.000072
# 11    4.000079
# 12    4.000087
# 13    4.000094
# 14    4.000101
# 15    4.000107
# 16    4.000114
# 17    4.000121
# 18    4.000127
# 19    4.000134
# 20    4.000141
# 21    4.000149
# 22    4.000156
# 23    4.000164
# 24    4.000174
# 25    4.000182
# 26    4.000197
# 27    4.000204
# 28    4.000211
# 29    4.000219
# Name: B, dtype: float64

# %% [markdown]
# ### 5. run

# %%
df = pd.read_csv('gradient5.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
df.A.plot(ax=axes[0])
df.B.plot(ax=axes[1])
fig.suptitle('5. run gradient', fontsize = 16 )
# Out:
# Text(0.5, 0.98, '5. run gradient')

# %%
df = pd.read_csv('parameters5.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
df.A.plot(ax=axes[0])
df.B.plot(ax=axes[1])
fig.suptitle('5. run parameters', fontsize = 16 )
# Out:
# Text(0.5, 0.98, '5. run parameters')

# %% [markdown]
# ### 4. run

# %%
df = pd.read_csv('gradient4.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
df.A.plot(ax=axes[0])
df.B.plot(ax=axes[1])
fig.suptitle('4. run gradient', fontsize = 16 )
# Out:
# Text(0.5, 0.98, '4. run gradient')

# %% [markdown]
# ### 3. run

# %%
df = pd.read_csv('gradient3.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
df.A.plot(ax=axes[0])
df.B.plot(ax=axes[1])
fig.suptitle('3. run gradient', fontsize = 16 )
# Out:
# Text(0.5, 0.98, '3. run gradient')

# %% [markdown]
# # Positive gradient

# %% [markdown]
# ### 1. run

# %%
df = pd.read_csv('gradient_pos1.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
df.A.plot(ax=axes[0])
df.B.plot(ax=axes[1])
fig.suptitle('1. run positive gradient', fontsize = 16 )
# Out:
# Text(0.5, 0.98, '1. run positive gradient')

# %% [markdown]
# ### 2. run

# %%
df = pd.read_csv('gradient_pos2.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
df.A.plot(ax=axes[0])
df.B.plot(ax=axes[1])
fig.suptitle('2. run positive gradient', fontsize = 16 )
# Out:
# Text(0.5, 0.98, '2. run positive gradient')

# %%
df = pd.read_csv('parameters_pos_2.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
df.A.plot(ax=axes[0])
df.B.plot(ax=axes[1])
fig.suptitle('2. run parameters (positive gradient)', fontsize = 16 )
# Out:
# Text(0.5, 0.98, '2. run parameters (positive gradient)')

# %% [markdown]
# # Fivepoint difference

# %% [markdown]
# ### 1. run

# %%
df = pd.read_csv('gradient_fivepoint1.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
df.A.plot(ax=axes[0])
df.B.plot(ax=axes[1])
fig.suptitle('1. run fivepoint difference', fontsize = 16 )
# Out:
# Text(0.5, 0.98, '2. run positive gradient')

# %% [markdown]
# ### 2. run

# %%
df = pd.read_csv('gradient_fivepoint2.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
df.A.plot(ax=axes[0])
df.B.plot(ax=axes[1])
fig.suptitle('1. run fivepoint difference', fontsize = 16 )
# Out:
# Text(0.5, 0.98, '1. run fivepoint difference')

# %% [markdown]
# ## positive gradient

# %% [markdown]
# ### 1. run

# %%
df = pd.read_csv('data_fivepoint_positivegrad1_grad.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
df.A.plot(ax=axes[0])
df.B.plot(ax=axes[1])
fig.suptitle('1. run fivepoint difference', fontsize = 16 )
# Out:
# Text(0.5, 0.98, '1. run fivepoint difference')

# %%
df = pd.read_csv('data_fivepoint_positivegrad1_params.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
df.A.plot(ax=axes[0])
df.B.plot(ax=axes[1])
fig.suptitle('2. run parameters (positive gradient)', fontsize = 16 )
# Out:
# Text(0.5, 0.98, '2. run parameters (positive gradient)')

# %% [markdown]
# # 3. major run

# %% [markdown]
# ### 1. run

# %%
df = pd.read_csv('majorrun3_1_gradient.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
axes[0].scatter(x= df.index, y =  df.A)
axes[1].scatter(x= df.index, y =  df.B)
fig.suptitle('2. run gradient (positive gradient)', fontsize = 16 )
# Out:
# Text(0.5, 0.98, '2. run parameters (positive gradient)')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=29, step=1)

# %% [markdown]
# # 4. Major run

# %% [markdown]
# ## 1. run

# %% [markdown]
# ### 1. run

# %%
df = pd.read_csv('majorrun4_1_grad.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
axes[0].scatter(x= df.index, y =  df.A)
axes[1].scatter(x= df.index, y =  df.B)
fig.suptitle('1. run gradient', fontsize = 16 )
# Out:
# Text(0.5, 0.98, '1. run gradient')

# %% [markdown]
# ### 2. run

# %%
df = pd.read_csv('majorrun4_2_grad.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
axes[0].scatter(x= df.index, y =  df.A)
axes[1].scatter(x= df.index, y =  df.B)
fig.suptitle('2. run gradient', fontsize = 16 )
# Out:
# Text(0.5, 0.98, '2. run gradient')

# %%
df = pd.read_csv('majorrun4_2_params.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
axes[0].scatter(x= df.index, y =  df.A)
axes[1].scatter(x= df.index, y =  df.B)
fig.suptitle('2. run params', fontsize = 16 )
# Out:
# Text(0.5, 0.98, '2. run params')

# %% [markdown]
# ## 2. run

# %%
df = pd.read_csv('majorrun4_2_1_grad.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
axes[0].scatter(x= df.index, y =  df.A)
axes[1].scatter(x= df.index, y =  df.B)
fig.suptitle('1. run gradient', fontsize = 16 )
# Out:
# Text(0.5, 0.98, '1. run gradient')

# %%
df = pd.read_csv('majorrun4_2_1_params.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
axes[0].scatter(x= df.index, y =  df.A)
axes[1].scatter(x= df.index, y =  df.B)
fig.suptitle('1. run params', fontsize = 16 )
# Out:
# Text(0.5, 0.98, '1. run params')

# %% [markdown]
# ## 3.run

# %% [markdown]
# ### 1.run

# %%
df = pd.read_csv('majorrun4_3_1_grad.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
axes[0].scatter(x= df.index, y =  df.A)
axes[1].scatter(x= df.index, y =  df.B)
fig.suptitle('1. run gradient', fontsize = 16 )
# Out:
# Text(0.5, 0.98, '1. run gradient')

# %%
df = pd.read_csv('majorrun4_3_1_params.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
axes[0].scatter(x= df.index, y =  df.A)
axes[1].scatter(x= df.index, y =  df.B)
fig.suptitle('1. run gradient', fontsize = 16 )
# Out:
# Text(0.5, 0.98, '1. run gradient')

# %%
df.iloc[0:35, :].tail(8)
# Out:
#            A         B
# 27  0.990377  1.993612
# 28  0.990369  1.993378
# 29  0.990362  1.993145
# 30  0.990355  1.992911
# 31  0.993267  1.993003
# 32  0.995597  1.993105
# 33  0.997461  1.993216
# 34  0.998953  1.993333

# %% [markdown]
# ## 4. run

# %% [markdown]
# ### 1. run

# %%
df = pd.read_csv('majorrun4_4_1_grad.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
axes[0].scatter(x= df.index, y =  df.A)
axes[1].scatter(x= df.index, y =  df.B)
fig.suptitle('1. run gradient', fontsize = 16 )
# Out:
# Text(0.5, 0.98, '1. run gradient')

# %%
df = pd.read_csv('majorrun4_4_1_params.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
axes[0].scatter(x= df.index, y =  df.A)
axes[1].scatter(x= df.index, y =  df.B)
fig.suptitle('1. run gradient', fontsize = 16 )
# Out:
# Text(0.5, 0.98, '1. run gradient')

# %% [markdown]
# ### 2. run

# %%
df = pd.read_csv('majorrun4_4_2_grad.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
axes[0].scatter(x= df.index, y =  df.A)
axes[1].scatter(x= df.index, y =  df.B)
fig.suptitle('1. run gradient', fontsize = 16 )
# Out:
# Text(0.5, 0.98, '1. run gradient')

# %%
df = pd.read_csv('majorrun4_4_2_params.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
axes[0].scatter(x= df.index, y =  df.A)
axes[1].scatter(x= df.index, y =  df.B)
fig.suptitle('1. run gradient', fontsize = 16 )
# Out:
# Text(0.5, 0.98, '1. run gradient')

# %%
df.tail()
# Out:
#            A         B
# 36  1.000174  2.000008
# 37  1.000179  2.000009
# 38  1.000184  2.000009
# 39  1.000188  2.000009
# 40  1.000193  2.000009

# %% [markdown]
# ### 5. run

# %%
df = pd.read_csv('majorrun4_5_1_grad.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
axes[0].scatter(x= df.index, y =  df.A)
axes[1].scatter(x= df.index, y =  df.B)
fig.suptitle('1. run gradient', fontsize = 16 )
# Out:
# Text(0.5, 0.98, '1. run gradient')

# %%
df = pd.read_csv('majorrun4_5_1_params.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
axes[0].scatter(x= df.index, y =  df.A)
axes[1].scatter(x= df.index, y =  df.B)
fig.suptitle('1. run gradient', fontsize = 16 )
# Out:
# Text(0.5, 0.98, '1. run gradient')

# %%
len(df)
# Out:
# 70

# %% [markdown]
# ### 2. run

# %%
df = pd.read_csv('majorrun4_5_2_grad.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
axes[0].scatter(x= df.index, y =  df.A)
axes[1].scatter(x= df.index, y =  df.B)
fig.suptitle(' gradient', fontsize = 16 )
# Out:
# Text(0.5, 0.98, ' gradient')

# %%
df = pd.read_csv('majorrun4_5_2_params.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
axes[0].scatter(x= df.index, y =  df.A)
axes[1].scatter(x= df.index, y =  df.B)
fig.suptitle('params', fontsize = 16 )
# Out:
# Text(0.5, 0.98, 'params')

# %%
df
# Out:
#            A         B
# 0  -0.089920  0.013768
# 1   0.090915  0.007086
# 2  -0.090405  0.013534
# 3   0.091375  0.006873
# 4  -0.090884  0.013309
# ..       ...       ...
# 63  0.103729  0.002831
# 64 -0.103558  0.009083
# 65  0.104106  0.002744
# 66 -0.103941  0.008995
# 67  0.104482  0.002659
#
# [68 rows x 2 columns]

# %% [markdown]
# ### 3. run

# %%
df = pd.read_csv('majorrun4_5_3_grad.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
axes[0].scatter(x= df.index, y =  df.A)
axes[1].scatter(x= df.index, y =  df.B)
fig.suptitle('grad', fontsize = 16 )
# Out:
# Text(0.5, 0.98, 'grad')

# %%
df[df['A']<0]
# Out:
#            A         B
# 39 -0.000009 -0.001249
# 40 -0.000017 -0.001247
# 41 -0.000024 -0.001246
# 42 -0.000029 -0.001244
# 43 -0.000033 -0.001243
# ..       ...       ...
# 95 -0.000046 -0.001176
# 96 -0.000046 -0.001174
# 97 -0.000046 -0.001173
# 98 -0.000046 -0.001172
# 99 -0.000046 -0.001171
#
# [61 rows x 2 columns]

# %%
df = pd.read_csv('majorrun4_5_3_params.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
axes[0].scatter(x= df.index, y =  df.A)
axes[1].scatter(x= df.index, y =  df.B)
fig.suptitle('params', fontsize = 16 )
# Out:
# Text(0.5, 0.98, 'params')

# %%
df.loc[39, :]
# Out:
# A    3.100371
# B    3.893048
# Name: 39, dtype: float64

# %% [markdown]
# ### 4. run

# %%
df = pd.read_csv('majorrun4_5_4_grad.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
axes[0].scatter(x= df.index, y =  df.A)
axes[1].scatter(x= df.index, y =  df.B)
fig.suptitle('params', fontsize = 16 )
# Out:
# Text(0.5, 0.98, 'params')

# %%
df = pd.read_csv('majorrun4_5_4_params.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
axes[0].scatter(x= df.index, y =  df.A)
axes[1].scatter(x= df.index, y =  df.B)
fig.suptitle('params', fontsize = 16 )
# Out:
# Text(0.5, 0.98, 'params')

# %% [markdown]
# ### 5. run

# %%
df = pd.read_csv('majorrun4_5_5_grad.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
axes[0].scatter(x= df.index, y =  df.A)
axes[1].scatter(x= df.index, y =  df.B)
fig.suptitle('params', fontsize = 16 )
# Out:
# Text(0.5, 0.98, 'params')

# %%
df.tail()
# Out:
#             A         B
# 96  -0.000395 -0.007493
# 97  -0.000392 -0.007418
# 98  -0.000389 -0.007343
# 99  -0.000386 -0.007269
# 100 -0.000382 -0.007194

# %%
df = pd.read_csv('majorrun4_5_5_params.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
axes[0].scatter(x= df.index, y =  df.A)
axes[1].scatter(x= df.index, y =  df.B)
fig.suptitle('params', fontsize = 16 )
# Out:
# Text(0.5, 0.98, 'params')

# %% [markdown]
# ### 6.run

# %%
df = pd.read_csv('majorrun4_5_6_grad.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
axes[0].scatter(x= df.index, y =  df.A)
axes[1].scatter(x= df.index, y =  df.B)
fig.suptitle('params', fontsize = 16 )
# Out:
# Text(0.5, 0.98, 'params')

# %%
df = pd.read_csv('majorrun4_5_6_params.csv', names = ['A', 'B'])
fig, axes = plt.subplots(nrows= 1, ncols=2, figsize = (10,5))
axes[0].scatter(x= df.index, y =  df.A)
axes[1].scatter(x= df.index, y =  df.B)
fig.suptitle('params', fontsize = 16 )
# Out:
# Text(0.5, 0.98, 'params')
