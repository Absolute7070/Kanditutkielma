# %%
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# # main.f90

# %%
plt.pie(
    y, 
    labels = mylabels, 
    colors = mycolors,
    explode = myexplode, 
    startangle = 90, 
    autopct ='%.2f%%', 
    shadow =True, 
    textprops={'fontsize': 14} )

# %%
kokonaisaika = 125290.74288800001

data = [ 124317.70892300000 ,990.96070700000564, 1453*210+ 5462.2794570000005  ]
texts= ["termalisaatio", "energian laskemisen loput vaiheet", "parametrien optimointi"]

plt.figure(figsize=(6,6))
plt.pie(data, labels=texts, autopct='%.2f%%', textprops={'fontsize': 12})
plt.title("Fortran-ohjelman ajan käytön jakauma", fontsize = 15)
plt.legend(title = "Vaiheet:", loc="lower right")

# %%
data[0]/kokonaisaika, data[1]/kokonaisaika
# Out:
# (0.9922337920378537, 0.007909289099561378)

# %%
 5177/2088.17
# Out:
# 2.4792042793450726
