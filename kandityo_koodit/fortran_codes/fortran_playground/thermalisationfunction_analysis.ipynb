# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd

# %%
df= pd.read_csv("prob_test_data_trial_prob_data.txt", header= None, names = ['data'] )
df.plot()
# Out:
# <AxesSubplot:>

# %%
df= pd.read_csv("prob_test_data_old_prob_data.txt", header= None, names = ['data'] )
df.plot()
# Out:
# <AxesSubplot:>
